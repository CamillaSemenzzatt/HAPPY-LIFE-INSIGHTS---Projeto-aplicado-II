# %%
import pandas as pd

# merging two csv files
df = pd.concat(
    map(pd.read_csv, ['theglobaleconomy01.csv', 'theglobaleconomy02.csv']), ignore_index=True)
df.head()
# Out:
#        Country Code ContinentCode  Year  \
# 0  Afghanistan  AFG            AS  2000
# 1  Afghanistan  AFG            AS  2001
# 2  Afghanistan  AFG            AS  2002
# 3  Afghanistan  AFG            AS  2003
# 4  Afghanistan  AFG            AS  2004
#
#    Government spending as percent of GDP  Government debt as percent of GDP  \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                             345.98
# 3                                    NaN                             270.60
# 4                                    NaN                             244.97
#
#    Economic growth forecast  Inflation forecast  Unemployment rate forecast  \
# 0                       NaN                 NaN                         NaN
# 1                       NaN                 NaN                         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11401 entries, 0 to 11400
# Data columns (total 38 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Country                                                   11401 non-null  object
#  1   Code                                                      11401 non-null  object
#  2   ContinentCode                                             9948 non-null   object
#  3   Year                                                      11401 non-null  int64
#  4   Government spending as percent of GDP                     7498 non-null   float64
#  5   Government debt as percent of GDP                         4050 non-null   float64
#  6   Economic growth forecast                                  10816 non-null  float64
#  7   Inflation forecast                                        10730 non-null  float64
# ...

# %%
df.dtypes
# Out:
# Country                                                      object
# Code                                                         object
# ContinentCode                                                object
# Year                                                          int64
# Government spending as percent of GDP                       float64
# Government debt as percent of GDP                           float64
# Economic growth forecast                                    float64
# Inflation forecast                                          float64
# Unemployment rate forecast                                  float64
# Government effectiveness index (-2.5 weak; 2.5 strong)      float64
# Control of corruption (-2.5 weak; 2.5 strong)               float64
# Corruption Perceptions Index 100 = no corruption            float64
# Population size in millions                                 float64
# Health spending as percent of GDP                           float64
# ...

# %%
df.describe(include='all')
# Out:
#         Country   Code ContinentCode          Year  \
# count     11401  11401          9948  11401.000000
# unique      202    202             5           NaN
# top     Liberia    LBR            AF           NaN
# freq         58     58          3065           NaN
# mean        NaN    NaN           NaN   2013.828875
# std         NaN    NaN           NaN      8.302077
# min         NaN    NaN           NaN   2000.000000
# 25%         NaN    NaN           NaN   2007.000000
# 50%         NaN    NaN           NaN   2014.000000
# 75%         NaN    NaN           NaN   2021.000000
# max         NaN    NaN           NaN   2028.000000
#
#         Government spending as percent of GDP  \
# count                             7498.000000
# unique                                    NaN
# top                                       NaN
# freq                                      NaN
# mean                                16.300782
# std                                  6.822471
# ...

# %%
df[['Happiness Index 0 (unhappy) - 10 (happy)']].mean()
# Out:
# Happiness Index 0 (unhappy) - 10 (happy)    5.457168
# dtype: float64
